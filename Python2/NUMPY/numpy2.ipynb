# %% [markdown]
# Broadcasting

# %%
import numpy as np
a=np.array([0,1,2])

a.shape
# Out:
# (3,)

# %%
import numpy as np
a=np.tile(np.arange(0,40,10),(3,1))
print(a)

print("******************")
a=a.T
print(a)
# Out:
# [[ 0 10 20 30]
#  [ 0 10 20 30]
#  [ 0 10 20 30]]
# ******************
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]]

# %%
import numpy as np
a=np.tile(np.arange(0,40,10),(3,2))
print(a)

print("******************")
a=a.T
print(a)
# Out:
# [[ 0 10 20 30  0 10 20 30]
#  [ 0 10 20 30  0 10 20 30]
#  [ 0 10 20 30  0 10 20 30]]
# ******************
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]
#  [ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]]

# %%
b=np.array([0,1,2])
b
# Out:
# array([0, 1, 2])

# %%
a + b
# Out:
# array([[ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32],
#        [ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])

# %%
a=np.arange(0,40,10)
a.shape
# Out:
# (4,)

# %%
a=a[:,np.newaxis]
a.shape
# Out:
# (4, 1)

# %%
a
# Out:
# array([[ 0],
#        [10],
#        [20],
#        [30]])

# %%
a+b
# Out:
# array([[ 0,  1,  2],
#        [10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])

# %%
# 2D array of convert 1D Array:

a=np.array([[1,2,3],[4,5,6]])
a.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a.T #Transpose
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
a.T.ravel()
# Out:
# array([1, 4, 2, 5, 3, 6])

# %%
print(a.shape)
print(a)
# Out:
# (2, 3)
# [[1 2 3]
#  [4 5 6]]

# %%
b=a.ravel()
print(b)
# Out:
# [1 2 3 4 5 6]

# %%
b=b.reshape((2,3))
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b[0,0]=100
a
# Out:
# array([[100,   2,   3],
#        [  4,   5,   6]])
