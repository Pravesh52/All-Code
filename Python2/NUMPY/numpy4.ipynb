# %%
import pandas as pd
df=pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data=[('1/1/2017',32,6,'Rain'),
              ('1/2/2017',35,7,'Sunny'),
              ('1/3/2017',28,2,'snow'),
              ('1/4/2017',24,7,'snow'),
              ('1/5/2017',32,4,'Rain'),
              ('1/6/2017',31,2,'sunny'),
             ]
df=pd.DataFrame(weather_data,columns=['day','tempperature','windspeed','event'])
df
# Out:
#         day  tempperature  windspeed  event
# 0  1/1/2017            32          6   Rain
# 1  1/2/2017            35          7  Sunny
# 2  1/3/2017            28          2   snow
# 3  1/4/2017            24          7   snow
# 4  1/5/2017            32          4   Rain
# 5  1/6/2017            31          2  sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of         day  tempperature  windspeed  event
# 0  1/1/2017            32          6   Rain
# 1  1/2/2017            35          7  Sunny
# 2  1/3/2017            28          2   snow
# 3  1/4/2017            24          7   snow
# 4  1/5/2017            32          4   Rain
# 5  1/6/2017            31          2  sunny>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of         day  tempperature  windspeed  event
# 0  1/1/2017            32          6   Rain
# 1  1/2/2017            35          7  Sunny
# 2  1/3/2017            28          2   snow
# 3  1/4/2017            24          7   snow
# 4  1/5/2017            32          4   Rain
# 5  1/6/2017            31          2  sunny>

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     snow
# 3     snow
# 4     Rain
# 5    sunny
# Name: event, dtype: object

# %%
df[2:5]
# slicing
# Out:
#         day  tempperature  windspeed event
# 2  1/3/2017            28          2  snow
# 3  1/4/2017            24          7  snow
# 4  1/5/2017            32          4  Rain

# %%
df[['day','event']]
# get 2 or more columns
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   snow
# 3  1/4/2017   snow
# 4  1/5/2017   Rain
# 5  1/6/2017  sunny

# %%
df['tempperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: tempperature, dtype: int64

# %%
df['tempperature'].max()
# Out:
# np.int64(35)

# %%
df['tempperature'].min()
# Out:
# np.int64(24)

# %%
df['tempperature'].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: tempperature, dtype: float64

# %%
df[df.tempperature==df.tempperature.max()]
# Out:
#         day  tempperature  windspeed  event
# 1  1/2/2017            35          7  Sunny

# %%
df[df.tempperature==df.tempperature.min()]
# Out:
#         day  tempperature  windspeed event
# 3  1/4/2017            24          7  snow

# %%
df.day[df.tempperature==df.tempperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
#read excel file
# %pip install xlrd
# %pip install openpyxl
df=pd.read_excel('weather_data.xlsx')
df
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
